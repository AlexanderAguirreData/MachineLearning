# %%
import pandas as pandas

base = pandas.read_csv("Tabla.csv")

# %%
base
# Out:
#      Economy_Label  Year  \
# 0      Afghanistan  2006
# 1      Afghanistan  2007
# 2      Afghanistan  2008
# 3      Afghanistan  2009
# 4      Afghanistan  2010
# ...            ...   ...
# 1634         Yemen  2008
# 1635         Yemen  2009
# 1636         Yemen  2010
# 1637         Yemen  2011
# 1638         Yemen  2012
#
#       Total function_US_dollars_at_current_prices_in_millions_Value  \
# 0                                                2229.0
# 1                                                3303.0
# 2                                                9288.0
# 3                                                8940.0
# 4                                               12898.0
# ...                                                 ...
# 1634                                            11151.0
# 1635                                             9003.0
# 1636                                             9519.0
# 1637                                             8416.0
# ...

# %%
Perú = base[base["Economy_Label"]=="Peru"]

# %%
Perú
# Out:
#      Economy_Label  Year  \
# 1128          Peru  2000
# 1129          Peru  2001
# 1130          Peru  2002
# 1131          Peru  2003
# 1132          Peru  2004
# 1133          Peru  2005
# 1134          Peru  2006
# 1135          Peru  2007
# 1136          Peru  2008
# 1137          Peru  2009
# 1138          Peru  2010
# 1139          Peru  2011
# 1140          Peru  2012
# 1141          Peru  2013
# 1142          Peru  2014
# 1143          Peru  2015
# 1144          Peru  2016
# 1145          Peru  2017
# 1146          Peru  2018
# 1147          Peru  2019
# 1148          Peru  2020
#
#       Total function_US_dollars_at_current_prices_in_millions_Value  \
# 1128                                            10764.0
# 1129                                             9425.0
# 1130                                             9605.0
# 1131                                            11011.0
# 1132                                            12064.0
# ...

# %%
Perú2 = Perú[["Year", "Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value"]]

# %%
Perú2
# Out:
#       Year  \
# 1128  2000
# 1129  2001
# 1130  2002
# 1131  2003
# 1132  2004
# 1133  2005
# 1134  2006
# 1135  2007
# 1136  2008
# 1137  2009
# 1138  2010
# 1139  2011
# 1140  2012
# 1141  2013
# 1142  2014
# 1143  2015
# 1144  2016
# 1145  2017
# 1146  2018
# 1147  2019
# 1148  2020
#
#       Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value
# 1128                                              389.0
# 1129                                              365.0
# 1130                                              334.0
# 1131                                              294.0
# 1132                                              315.0
# 1133                                              325.0
# 1134                                              500.0
# 1135                                              562.0
# 1136                                              748.0
# 1137                                              872.0
# ...

# %%
seaborn.scatterplot(x = "Year", y = "Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value", data = Perú2, s= Perú2 ["Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value"]/100)
# Out:
# <Axes: xlabel='Year', ylabel='Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value'>

# %%
Perú2.describe()
# Out:
#               Year  \
# count    21.000000
# mean   2010.000000
# std       6.204837
# min    2000.000000
# 25%    2005.000000
# 50%    2010.000000
# 75%    2015.000000
# max    2020.000000
#
#        Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value
# count                                          21.000000
# mean                                          873.666667
# std                                           445.888476
# min                                           294.000000
# 25%                                           389.000000
# 50%                                           872.000000
# 75%                                          1263.000000
# max                                          1532.000000

# %%
Perú2.corr()
# Out:
#                                                         Year  \
# Year                                                1.000000
# Agriculture, forestry, fishing and hunting_US_d...  0.956567
#
#                                                     Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value
# Year                                                                                         0.956567
# Agriculture, forestry, fishing and hunting_US_d...                                           1.000000

# %%
#Preparar modelo de regresión líneal
x=Perú2["Year"]
y = Perú2["Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value"]

# %%
y
# Out:
# 1128     389.0
# 1129     365.0
# 1130     334.0
# 1131     294.0
# 1132     315.0
# 1133     325.0
# 1134     500.0
# 1135     562.0
# 1136     748.0
# 1137     872.0
# 1138     952.0
# 1139     775.0
# 1140    1164.0
# 1141    1218.0
# 1142    1302.0
# 1143    1416.0
# 1144    1165.0
# 1145    1361.0
# 1146    1263.0
# 1147    1532.0
# 1148    1495.0
# Name: Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value, dtype: float64

# %%
import numpy as np

# %%
xprocesada= x.values.reshape(-1,1)

# %%
yprocesada = y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()

# %%
modelo.fit(xprocesada, yprocesada)
# Out:
# LinearRegression()

# %%
# Prueba con número que está en la tabla Perú2
modelo.predict([[2017]])
# Out:
# array([[1354.84848485]])

# %%
#Pruebas con años que no es parte de la tabla Perú2
modelo.predict([[2021]])
# Out:
# array([[1629.80952381]])

# %%
modelo.predict([[2022]])
# Out:
# array([[1698.54978355]])

# %%
modelo.predict([[2023]])
# Out:
# array([[1767.29004329]])

# %%
modelo.score(xprocesada,yprocesada)
# Out:
# 0.9150199651534552

# %%
seaborn.scatterplot(x = "Year", y = "Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value", data = Perú2, s= Perú2 ["Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value"]/100)
# Out:
# <Axes: xlabel='Year', ylabel='Agriculture, forestry, fishing and hunting_US_dollars_at_current_prices_in_millions_Value'>
